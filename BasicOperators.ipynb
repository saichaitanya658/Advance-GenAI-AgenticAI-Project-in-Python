# %% [markdown]
# # Python basic operators

# %%
#arithematic operators

# %%
a1 = 5
a2 = 6
add = a1 + a2
print(add)
# Out:
# 11

# %%
sub = a1-a2
print(sub)
# Out:
# -1

# %%
mul = a1*a2
print(mul)
# Out:
# 30

# %%
flt_div = a1/a2
print(flt_div)
# Out:
# 0.8333333333333334

# %%
int_div = a1//a2
print(int_div)
# Out:
# 0

# %%
mod = a1%a2
print(mod)
# Out:
# 5

# %%
pwr = a1**a2
print(pwr)
# Out:
# 15625

# %%
#assignment

# %%
a = 3
a
# Out:
# 3

# %%
a += 4
a
# Out:
# 7

# %%
a -= 5
a
# Out:
# 2

# %%
a *= 5
a
# Out:
# 10

# %%
a /= 2
a
# Out:
# 2.5

# %%
a //=2
a
# Out:
# 1.0

# %%
#unary

# %%
b = 10
b
# Out:
# 10

# %%
c = -b
c
# Out:
# -10

# %%
#relational

# %%
a = 10
b = 15

# %%
a==b
# Out:
# False

# %%
a<b
# Out:
# True

# %%
a>b
# Out:
# False

# %%
a<=b
# Out:
# True

# %%
a>=b
# Out:
# False

# %%
a!=b
# Out:
# True

# %%
#logical

# %%
x = True 
y = False

# %%
z = x and y
z
# Out:
# False

# %%
y=True

# %%
z = x and y
z
# Out:
# True

# %%
x = True 
y = False

# %%
z = x or y
z
# Out:
# True

# %%
x = True 
y = True

# %%
z = x or y
z
# Out:
# True

# %%
x = False
y = False

# %%
z = x or y
# Out:
# False

# %%
x = False

# %%
z= not(x)
z
# Out:
# True

# %%
y = True

# %%
z = not(y)
z
# Out:
# False
