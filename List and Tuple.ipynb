# %% [markdown]
# # DATA STRUCTURES

# %% [markdown]
# # LIST

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
l = [1,2,3,4,5]
l
# Out:
# [1, 2, 3, 4, 5]

# %%
l.append(10)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 10]

# %%
l.append(15)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 10, 15]

# %%
l1 = []

# %%
l1 = l.copy()

# %%
l1
# Out:
# [1, 2, 3, 4, 5, 10, 15]

# %%
l1.clear()

# %%
l1
# Out:
# []

# %%
del l1

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
l
# Out:
# [1, 2, 3, 4, 5, 10, 15]

# %%
l.count(3)
# Out:
# 1

# %%
l.append(10)

# %%
l.count(10)
# Out:
# 2

# %%
l1 = [10,20,30,40]

# %%
l
# Out:
# [1, 2, 3, 4, 5, 10, 15, 10]

# %%
l.extend(l1)

# %%
print(l)
# Out:
# [1, 2, 3, 4, 5, 10, 15, 10, 10, 20, 30, 40]

# %%
l.index(5)
# Out:
# 4

# %%
l.index(1)
# Out:
# 0

# %%
l.insert(5,6)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 10, 15, 10, 10, 20, 30, 40]

# %%
l.insert(8,20)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 10, 15, 20, 10, 10, 20, 30, 40]

# %%
l.pop()
# Out:
# 40

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 10, 15, 20, 10, 10, 20, 30]

# %%
l.pop()
# Out:
# 30

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 10, 15, 20, 10, 10, 20]

# %%
l.pop(9)
# Out:
# 10

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 10, 15, 20, 10, 20]

# %%
l.pop(9)
# Out:
# 10

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 10, 15, 20, 20]

# %%
l.remove(20)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 10, 15, 20]

# %%
l.remove(15)

# %%
l
# Out:
# [1, 2, 3, 4, 5, 6, 10, 20]

# %%
l.remove(100)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 l.remove(100)
#
# ValueError: list.remove(x): x not in list

# %%
l.reverse()

# %%
l
# Out:
# [20, 10, 6, 5, 4, 3, 2, 1]

# %%
l2 = [5,2,7,9,1,10,12,30,3]
l2
# Out:
# [5, 2, 7, 9, 1, 10, 12, 30, 3]

# %%
l2.sort()

# %%
l2
# Out:
# [1, 2, 3, 5, 7, 9, 10, 12, 30]

# %% [markdown]
# # indexing and slicing

# %%
l
# Out:
# [20, 10, 6, 5, 4, 3, 2, 1]

# %%
l2
# Out:
# [1, 2, 3, 5, 7, 9, 10, 12, 30]

# %%
l2[:]
# Out:
# [1, 2, 3, 5, 7, 9, 10, 12, 30]

# %%
l2[0:5]
# Out:
# [1, 2, 3, 5, 7]

# %%
l2[3:6]
# Out:
# [5, 7, 9]

# %%
l3 = [1,'sai',1+2j,True,6.7]
l3
# Out:
# [1, 'sai', (1+2j), True, 6.7]

# %%
l3[2:5]
# Out:
# [(1+2j), True, 6.7]

# %%
l2
# Out:
# [1, 2, 3, 5, 7, 9, 10, 12, 30]

# %%
l2[::-1]
# Out:
# [30, 12, 10, 9, 7, 5, 3, 2, 1]

# %%
l2[0:9:2]
# Out:
# [1, 3, 7, 10, 30]

# %%
l2[-1:-9:-3]
# Out:
# [30, 9, 3]

# %%
l2
# Out:
# [1, 2, 3, 5, 7, 9, 10, 12, 30]

# %%
l2[8] = 20

# %%
l2
# Out:
# [1, 2, 3, 5, 7, 9, 10, 12, 20]

# %%
l2[7]=15

# %%
l2
# Out:
# [1, 2, 3, 5, 7, 9, 10, 15, 20]

# %%
l4 = ['ant','eat','dog','cat','bat']

# %%
l4
# Out:
# ['ant', 'eat', 'dog', 'cat', 'bat']

# %%
l4.sort()

# %%
l4
# Out:
# ['ant', 'bat', 'cat', 'dog', 'eat']

# %% [markdown]
# # TUPLE

# %%
t = ()

# %%
t
# Out:
# ()

# %%
type(t)
# Out:
# tuple

# %%
t = (2,5,7,3,1,9,7)
t
# Out:
# (2, 5, 7, 3, 1, 9, 7)

# %%
t.count(7)
# Out:
# 2

# %%
t.index(1)
# Out:
# 4

# %%
t[1]
# Out:
# 5

# %%
t[:]
# Out:
# (2, 5, 7, 3, 1, 9, 7)

# %%
t[::1]
# Out:
# (2, 5, 7, 3, 1, 9, 7)

# %%
t[0:7:2]
# Out:
# (2, 7, 1, 7)

# %%
t[::-1]
# Out:
# (7, 9, 1, 3, 7, 5, 2)

# %%
t[-1:-7:-3]
# Out:
# (7, 3)

# %%
t[-4]
# Out:
# 3
