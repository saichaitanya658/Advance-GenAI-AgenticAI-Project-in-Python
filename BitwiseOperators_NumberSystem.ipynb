# %% [markdown]
# # Bitwise operators

# %%
#bitwise and(&)--1-1=1,all other 0

# %%
a = 12
b = 13
x = a & b
print(x)
# Out:
# 12

# %%
a = 15
b = 10
x = a & b
print(x)
# Out:
# 10

# %%
c = 15
x = a & c
print(x)
# Out:
# 15

# %%
# bitwise or(|) --0-0=0,all other 1

# %%
print(a)
print(b)
# Out:
# 15
# 10

# %%
x= a | b
print(x)
# Out:
# 15

# %%
a = 12
b = 13

# %%
x = a|b
print(x)
# Out:
# 13

# %%
# bitwise xor(^)--1-1=0,0-0=0,all other 1

# %%
a = 12
b = 13

# %%
x = a^b
print(x)
# Out:
# 1

# %%
a = 15
b = 10
x = a^b
print(x)
# Out:
# 5

# %%
#left shift(<<)--adds a bit

# %%
a
# Out:
# 15

# %%
a<<1
# Out:
# 30

# %%
b
# Out:
# 10

# %%
b<<2
# Out:
# 40

# %%
#right shift(>>)--removes a bit

# %%
a
# Out:
# 15

# %%
a>>1
# Out:
# 7

# %%
b
# Out:
# 10

# %%
b>>1
# Out:
# 5

# %%
a
# Out:
# 15

# %%
b>>2
# Out:
# 2

# %% [markdown]
# # Number system

# %%
#binary

# %%
bin(15)
# Out:
# '0b1111'

# %%
a = bin(15)
print(a)
# Out:
# 0b1111

# %%
b = int(0b1111)
print(b)
# Out:
# 15

# %%
#octal

# %%
oct(15)
# Out:
# '0o17'

# %%
c = oct(15)

# %%
c
# Out:
# '0o17'

# %%
c = int(0o17)

# %%
c
# Out:
# 15

# %%
0o17
# Out:
# 15

# %%
#decimal and hexadecimal

# %%
hex(15)
# Out:
# '0xf'

# %%
d = hex(15)
print(d)
# Out:
# 0xf

# %%
0xe
# Out:
# 14

# %%
0xd
# Out:
# 13

# %%
0xc
# Out:
# 12

# %%
0xb
# Out:
# 11

# %%
0xa
# Out:
# 10

# %%
e = int(0xa)

# %%
e
# Out:
# 10

# %%
f = hex(30)

# %%
f
# Out:
# '0x1e'

# %%
g = int(0x1e)

# %%
g
# Out:
# 30

# %% [markdown]
# # Print

# %%
a =10
b = 20
add = a+b
print('the addition of',a,'and',b,'is',add)
# Out:
# the addition of 10 and 20 is 30

# %%
a = 'sai'
b = 21
c = 'Hyd'
print('my name is',a,'i am',b,'from',c)
# Out:
# my name is sai i am 21 from Hyd

# %% [markdown]
# # Print Format

# %%
a =10
b = 20
add = a+b
print('the addition of {} and {} is {}'.format(a,b,add))
# Out:
# the addition of 10 and 20 is 30

# %%
a =10
b = 20
sub = a-b
print('the sibtraction of {} and {} is {}'.format(a,b,sub))
# Out:
# the sibtraction of 10 and 20 is -10

# %%
a = 'sai'
b = 21
c = 'Hyd'
print('my name is {} i am {} from {}'.format(a,b,c))
# Out:
# my name is sai i am 21 from Hyd

# %% [markdown]
# # Short Format

# %%
a =10
b = 20
add = a+b
print(f'the add of {a} and {b} is {add}')
# Out:
# the add of 10 and 20 is 30

# %%
a =10
b = 20
mul = a*b
print(f'the multiplication of {a} and {b} is {mul}')
# Out:
# the multiplication of 10 and 20 is 200

# %%
a = 'sai'
b = 21
c = 'Hyd'
print(f'my name is {a} i am {b} from {c}')
# Out:
# my name is sai i am 21 from Hyd
