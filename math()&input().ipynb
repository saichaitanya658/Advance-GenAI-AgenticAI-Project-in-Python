# %% [markdown]
# # math()

# %%
import math
a = math.sqrt(25)
print(a)
# Out:
# 5.0

# %%
math.sqrt(49)
# Out:
# 7.0

# %%
from math import pow,ceil
b = math.pow(2,3)
print(b)
# Out:
# 8.0

# %%
c = ceil(5.7)
print(c)
# Out:
# 6

# %%
d = floor(5.7)
print(d)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 d = floor(5.7)
#       2 print(d)
#
# NameError: name 'floor' is not defined

# %%
from math import*

# %%
d = floor(5.7)
print(d)
# Out:
# 5

# %%
pow(2,2)
# Out:
# 4.0

# %%
sqrt(81)
# Out:
# 9.0

# %% [markdown]
# # input()

# %%
a = int(input())
b = int(input())
# Out:
#  1
#  2

# %%
a = input()
b = input()
c = a + b
print(c)
# Out:
#  1
#  2
# 12

# %%
a = int(input())
b = int(input())
c = a + b
print(f'the additon of {a} and {b} is {c}')
# Out:
#  5
#  6
# the additon of 5 and 6 is 11

# %%
a = input()[3]
print(a)
# Out:
#  chaitu
# i

# %%
a = input('enter your number')[2:6]
print(a)
# Out:
# enter your number 123456789
# 3456
